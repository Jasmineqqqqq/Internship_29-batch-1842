# %%
print("olx data")
# Out:
# olx data

# %%
# import time  #importing libraries
# import selenium
# import pandas as pd 
# from selenium import webdriver
# from selenium.webdriver.chrome.service import Service
# from selenium.webdriver.common.by import By
# s=Service(r"C:\\Users\\Hinal\\Downloads\\chromedriver_win32\\chromedriver.exe")  #opening chrome
# driver = webdriver.Chrome(ChromeDriverManager().install()) #for mac
# driver.get(url)
# driver = webdriver.Chrome(service=s)    
# driver.maximize_window()
# driver.get("https://www.olx.in/cars_c84")  #getting the webpage of olx
# url = "https://www.olx.in/cars_c84"
# driver = webdriver.Chrome(ChromeDriverManager().install()) #for mac
# driver.get(url)


#Load
import pandas as pd
import numpy as np
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import time
import datetime
import os
from selenium.webdriver.chrome.service import Service #always import this or web driver gives truble
from selenium.webdriver.common.by import By #always import this or web driver gives truble
import time
from webdriver_manager.chrome import ChromeDriverManager # to manage the webdrivers for mac

url = 'https://www.olx.in/cars_c84'
#driver = webdriver.Chrome('chromedriver.exe')
driver = webdriver.Chrome(ChromeDriverManager().install()) #for mac
driver.get(url)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 105.0.5195
# Get LATEST chromedriver version for 105.0.5195 google-chrome
# Driver [/Users/sagarsalian/.wdm/drivers/chromedriver/mac64/105.0.5195.52/chromedriver] found in cache
# <ipython-input-44-0d42237cead9>:35: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install()) #for mac

# %%
brand=[] #empty list
varient=[] #empty list
manyear=[] #empty list
kms=[] #empty list
date=[] #empty list
fuel=[] #empty list
nowners=[] #empty list
loc=[] #empty list
transmission=[] #empty list
color=[] #empty list
sellertype=[] #empty list
price=[] #empty list
url=[] #empty list

time.sleep(5)
    
#fetching urls of each car to get more data    
for k in range(2):
    
    urls=driver.find_elements(By.XPATH,"//li[@class='_31j8e']/a")
    for i in urls[:]:
        url.append(i.get_attribute('href')) 
        
    if k==45:
        break
        
    #clicking on load more button
    nxt_button = driver.find_element(By.XPATH,"//div[@class='JbJAl']/button")                                    
    nxt_button.click()                                                   
    time.sleep(5)
        
for i in url:      #fetching data from Each Car's URL
    driver.get(i)   
    time.sleep(5)
    #fetching brand, model & manufacturing year of the car
    try:
        b=driver.find_element(By.XPATH,"//div[@class='_35xN1']")
        brand.append(b.text)
        print("olx car: {0}".format(b.text))
        #fetching the variant of the car 
        v=driver.find_element(By.XPATH,"//div[@class='_3tLee']")
        varient.append(v.text)

        #fetching the posting ad date of the car 
        d=driver.find_element(By.XPATH,"//div[@class='_1l939']/div[3]/div[2]/div[2]")
        date.append(d.text)

        #fetching the fuel type of the car 
        f=driver.find_element(By.XPATH,"//div[@class='aOxkz']/div[1]/div")
        fuel.append(f.text)

        #fetching the total number of driven kms of the car 
        k=driver.find_element(By.XPATH,"//div[@class='aOxkz']/div[2]/div")
        kms.append(k.text)

        #fetching the number of previous owners of the car 
        no=driver.find_element(By.XPATH,"//div[@class='_1l939']/div[1]/div[2]/div[2]")
        nowners.append(no.text + ' Owner') 

        #fetching the location of seller of the car 
        l=driver.find_element(By.XPATH,"//div[@class='_1l939']/div[2]/div[2]/div[2]")
        loc.append(l.text)

        #fetching the transmission of the car 
        t=driver.find_element(By.XPATH,"//div[@class='aOxkz']/div[3]/div")
        transmission.append(t.text)

        #fetching the seller of the car 
        s=driver.find_element(By.XPATH,"//span[@class='_1hYGL']")
        sellertype.append(s.text)

        #fetching the price of the car 
        p=driver.find_element(By.XPATH,"//div[@class='_3FkyT']")
        price.append(p.text)
    except:
        print("exception")
        break
    

    

Car = pd.DataFrame({})   #creating a datafrmae
Car['Brand & Model']=brand
Car['Varient']=varient
# 4             CNG         140000 KM    AUTOMATIC  Second Owner
# 5          PETROL        24000.0 KM       MANUAL     1st Owner
# 6          PETROL        136,000 KM       MANUAL     4th Owner
# 7          DIESEL        150,000 KM       MANUAL     1st Owner
# 8          PETROL         50,000 KM       MANUAL     1st Owner
# 9          DIESEL         85,000 KM       MANUAL     1st Owner
# 10         DIESEL        58000.0 KM    AUTOMATIC     2nd Owner
# 11         DIESEL        59632.0 KM       MANUAL     1st Owner
# 12         PETROL          10000 KM       MANUAL   First Owner
# 13         DIESEL         90,000 KM           --     3rd Owner
# 14         PETROL         64,000 KM       MANUAL     2nd Owner
# 15         DIESEL        130,000 KM       MANUAL     3rd Owner
# 16         DIESEL         75,000 KM       MANUAL     1st Owner
# 17         PETROL         83,000 KM       MANUAL     4th Owner
# 18         PETROL         80,000 KM       MANUAL     2nd Owner
# 19         PETROL        100,000 KM           --     1st Owner
# 20         PETROL        34610.0 KM    AUTOMATIC     1st Owner
# 21         DIESEL        61000.0 KM       MANUAL     1st Owner
# 22         PETROL        75000.0 KM       MANUAL     2nd Owner
# 23         DIESEL          90000 KM       MANUAL   First Owner
# 24         DIESEL         140000 KM    AUTOMATIC   Third Owner
# 25  CNG & HYBRIDS         81,500 KM       MANUAL     2nd Owner
# 26            LPG         95,481 KM       MANUAL     2nd Owner
# 27         PETROL         37,000 KM       MANUAL     2nd Owner
#
#                               Location  Date of Posting Ad Price (in ₹)
# 0               Noida Extension, Noida                  UP   ₹ 9,85,985
# 1                  Hulimavu, Bengaluru           07-SEP-22  ₹ 18,50,000
# 2                Lawyer's Colony, Agra           26-AUG-22   ₹ 8,70,000
# 3                Masab Tank, Hyderabad           Telangana   ₹ 1,90,000
# 4         Bapukaka Society, Mehmedabad             Gujarat   ₹ 3,50,000
# 5                      Dunlop, Kolkata           11-SEP-22   ₹ 9,45,000
# 6                Gopalwada, Mandamarri           11-SEP-22     ₹ 70,000
# 7         Raviendra Nagar, Mahbubnagar           11-SEP-22   ₹ 1,60,000
# 8              Talab Darwaja, Junagadh           11-SEP-22   ₹ 2,25,000
# 9                Miyan Ganj, Hyderabad           11-SEP-22   ₹ 4,30,000
# 10                     Chembur, Mumbai           11-SEP-22   ₹ 4,15,000
# 11               Dilshad Garden, Delhi           11-SEP-22   ₹ 4,10,000
# 12              Veerasandra, Bengaluru  Other minor issues   ₹ 7,80,000
# 13        China Jaggampeta, Pithapuram           11-SEP-22   ₹ 2,20,000
# 14                Gujjar Colony, Jammu           11-SEP-22   ₹ 6,55,000
# 15                Tokarkhada, Silvassa           11-SEP-22   ₹ 2,25,000
# 16         Akali Market Area, Amritsar           11-SEP-22   ₹ 2,49,999
# 17                   Kovai Nagar, Bhuj           11-SEP-22   ₹ 1,05,000
# 18               Mahadev Nagar, Boisar           11-SEP-22   ₹ 2,50,000
# 19     Industrial Area Phase 9, Mohali           11-SEP-22     ₹ 68,000
# 20                    Vadsar, Vadodara           10-MAR-22   ₹ 4,99,000
# 21                 Brijlalpura, Jaipur           01-SEP-22   ₹ 2,20,000
# 22           Dr Mukherjee Nagar, Delhi           09-SEP-22   ₹ 3,25,000
# 23                  Miyapur, Hyderabad           Telangana   ₹ 3,45,000
# 24           Kamakya Layout, Bengaluru           Karnataka   ₹ 3,20,000
# 25                               Erich           11-SEP-22   ₹ 2,70,000
# 26  Chinna Modachur, Gobichettipalayam           11-SEP-22   ₹ 1,23,000
# 27                 Arya Village, Hansi           11-SEP-22   ₹ 2,20,000
